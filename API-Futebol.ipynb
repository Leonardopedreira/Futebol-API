# %%
import requests
import curl
import pandas as pd
import json

# %%
test_token = 'test_96b721100e14be650e313678d17fc9'
header = { "Authorization": "Bearer live_434eab0b4893131a88c03653e5a8a6" }

futebol = requests.get('https://api.api-futebol.com.br/v1/campeonatos/2/rodadas/311',headers=header)
print(futebol)
# Out:
# <Response [404]>

# %%
data_dict = futebol.json()
data_dict['fases']
# Out:
# [{'fase_id': 310,
#   'edicao': {'edicao_id': 69,
#    'temporada': '2023',
#    'nome': 'Copa do Brasil 2023',
#    'nome_popular': 'Copa do Brasil 2023',
#    'slug': 'copa-do-brasil-2023'},
#   'nome': 'Primeira Fase',
#   'slug': 'primeira-fase',
#   'status': 'finalizado',
#   'decisivo': False,
#   'eliminatorio': True,
#   'ida_e_volta': False,
#   'tipo': 'mata-mata',
#   'grupos': [],
#   'chaves': [],
#   'rodadas': [],
#   'proxima_fase': {'fase_id': 311,
#    'nome': 'Segunda Fase',
#    'slug': 'segunda-fase',
#    'tipo': 'mata-mata',
#    '_link': '/v1/campeonatos/2/fases/311'},
#   'fase_anterior': None,
#   '_link': '/v1/campeonatos/2/fases/310'},
#  {'fase_id': 311,
#   'edicao': {'edicao_id': 69,
#    'temporada': '2023',
#    'nome': 'Copa do Brasil 2023',
#    'nome_popular': 'Copa do Brasil 2023',
#    'slug': 'copa-do-brasil-2023'},
#   'nome': 'Segunda Fase',
#   'slug': 'segunda-fase',
#   'status': 'finalizado',
#   'decisivo': False,
# ...

# %%
data_dict = json.loads(futebol)

print(data_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_16500/4039810143.py in <module>
# ----> 1 data_dict = json.loads(futebol)
#       2
#       3 print(data_dict)
#
# x:\Anaconda\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337     else:
#     338         if not isinstance(s, (bytes, bytearray)):
# --> 339             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                             f'not {s.__class__.__name__}')
#     341         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not Response
